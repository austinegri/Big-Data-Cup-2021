# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %%
# df = pd.read_csv("../hackathon_womens.csv")
# df = pd.read_csv("../hackathon_scouting.csv")
df = pd.read_csv("../hackathon_nwhl.csv")
df.head()
# Out:
#     game_date            Home Team     Away Team  Period  Clock  \
# 0  2021-01-23  Minnesota Whitecaps  Boston Pride       1  20:00
# 1  2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:58
# 2  2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:57
# 3  2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:55
# 4  2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:53
#
#    Home Team Skaters  Away Team Skaters  Home Team Goals  Away Team Goals  \
# 0                  5                  5                0                0
# 1                  5                  5                0                0
# 2                  5                  5                0                0
# 3                  5                  5                0                0
# 4                  5                  5                0                0
#
#            Team           Player          Event  X Coordinate  Y Coordinate  \
# 0  Boston Pride  Jillian Dempsey    Faceoff Win           100            43
# 1  Boston Pride    McKenna Brand  Puck Recovery           107            40
# 2  Boston Pride    McKenna Brand     Zone Entry           125            28
# 3  Boston Pride    McKenna Brand           Shot           131            28
# 4  Boston Pride  Tereza Vanisova    Faceoff Win           169            21
#
#    Detail 1 Detail 2 Detail 3 Detail 4            Player 2  X Coordinate 2  \
# 0  Backhand      NaN      NaN      NaN  Stephanie Anderson             NaN
# 1       NaN      NaN      NaN      NaN                 NaN             NaN
# 2   Carried      NaN      NaN      NaN         Maddie Rowe             NaN
# 3  Snapshot   On Net        t        f                 NaN             NaN
# 4  Backhand      NaN      NaN      NaN  Stephanie Anderson             NaN
#
#    Y Coordinate 2
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df[df['Event'] == 'Goal'].head()
# Out:
#        game_date            Home Team          Away Team  Period  Clock  \
# 387   2021-01-23  Minnesota Whitecaps       Boston Pride       1   6:42
# 423   2021-01-23  Minnesota Whitecaps       Boston Pride       1   5:40
# 879   2021-01-23  Minnesota Whitecaps       Boston Pride       2   8:02
# 2382  2021-01-23       Buffalo Beauts  Connecticut Whale       2  15:54
# 3052  2021-01-23       Buffalo Beauts  Connecticut Whale       3  14:32
#
#       Home Team Skaters  Away Team Skaters  Home Team Goals  Away Team Goals  \
# 387                   5                  5                0                0
# 423                   5                  5                0                1
# 879                   5                  5                1                1
# 2382                  5                  5                0                0
# 3052                  5                  4                0                1
#
#                      Team             Player Event  X Coordinate  \
# 387          Boston Pride  Christina Putigna  Goal           175
# 423   Minnesota Whitecaps       Jonna Curtis  Goal           180
# 879   Minnesota Whitecaps  Winny Brodt-Brown  Goal           188
# 2382    Connecticut Whale      Kayla Friesen  Goal           144
# 3052       Buffalo Beauts    Kristin Lewicki  Goal           168
#
#       Y Coordinate   Detail 1 Detail 2 Detail 3 Detail 4 Player 2  \
# 387             44   Snapshot   On Net        f        f      NaN
# 423             39   Snapshot   On Net        f        f      NaN
# 879             55   Snapshot   On Net        t        f      NaN
# 2382            15   Snapshot   On Net        t        f      NaN
# 3052            28  Wristshot   On Net        t        f      NaN
#
#       X Coordinate 2  Y Coordinate 2
# 387              NaN             NaN
# 423              NaN             NaN
# 879              NaN             NaN
# 2382             NaN             NaN
# 3052             NaN             NaN

# %%
teams = set(df['Home Team']) | set(df['Away Team'])
teams
# Out:
# {'Boston Pride',
#  'Buffalo Beauts',
#  'Connecticut Whale',
#  'Metropolitan Riveters',
#  'Minnesota Whitecaps',
#  'Toronto Six'}

# %%
passes = df[(df['Event'] == 'Play')]
failed_passes = df[(df['Event'] == 'Incomplete Play')]
passes
# Out:
#         game_date            Home Team     Away Team  Period  Clock  \
# 8      2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:47
# 9      2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:43
# 11     2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:40
# 17     2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:28
# 22     2021-01-23  Minnesota Whitecaps  Boston Pride       1  19:17
# ...           ...                  ...           ...     ...    ...
# 26871  2021-02-01       Buffalo Beauts  Boston Pride       3   0:34
# 26874  2021-02-01       Buffalo Beauts  Boston Pride       3   0:23
# 26875  2021-02-01       Buffalo Beauts  Boston Pride       3   0:09
# 26878  2021-02-01       Buffalo Beauts  Boston Pride       3   0:06
# 26881  2021-02-01       Buffalo Beauts  Boston Pride       3   0:03
#
#        Home Team Skaters  Away Team Skaters  Home Team Goals  Away Team Goals  \
# 8                      5                  5                0                0
# 9                      5                  5                0                0
# 11                     5                  5                0                0
# 17                     5                  5                0                0
# 22                     5                  5                0                0
# ...                  ...                ...              ...              ...
# 26871                  4                  5                1                7
# 26874                  4                  5                1                7
# 26875                  4                  5                1                7
# 26878                  4                  5                1                7
# 26881                  4                  5                1                7
#
#                       Team              Player Event  X Coordinate  \
# 8      Minnesota Whitecaps  Stephanie Anderson  Play           157
# 9      Minnesota Whitecaps      Meghan Lorence  Play           193
# 11            Boston Pride   Mallory Souliotis  Play             3
# 17            Boston Pride   Mallory Souliotis  Play            12
# 22            Boston Pride   Mallory Souliotis  Play            25
# ...                    ...                 ...   ...           ...
# 26871         Boston Pride      Samantha Davis  Play           179
# 26874         Boston Pride      Samantha Davis  Play           195
# 26875         Boston Pride    Taylor Turnquist  Play           159
# 26878       Buffalo Beauts         Megan Delay  Play             8
# 26881         Boston Pride       Briana Mastel  Play           132
#
#        Y Coordinate  Detail 1 Detail 2 Detail 3 Detail 4            Player 2  \
# 8                 0  Indirect      NaN      NaN      NaN      Meghan Lorence
# 9                20    Direct      NaN      NaN      NaN          Haley Mack
# 11               49    Direct      NaN      NaN      NaN  Taylor Wenczkowski
# 17               33    Direct      NaN      NaN      NaN  Taylor Wenczkowski
# 22                3  Indirect      NaN      NaN      NaN      Samantha Davis
# ...             ...       ...      ...      ...      ...                 ...
# 26871            79  Indirect      NaN      NaN      NaN         Lexie Laing
# 26874            47  Indirect      NaN      NaN      NaN    Taylor Turnquist
# 26875            49    Direct      NaN      NaN      NaN      Samantha Davis
# 26878            61  Indirect      NaN      NaN      NaN  Cassidy MacPherson
# 26881             4  Indirect      NaN      NaN      NaN         Lexie Laing
#
#        X Coordinate 2  Y Coordinate 2
# 8               198.0            38.0
# 9               196.0            33.0
# 11               37.0            70.0
# 17               61.0            85.0
# 22               57.0             3.0
# ...               ...             ...
# 26871           197.0            57.0
# 26874           138.0            83.0
# 26875           171.0            61.0
# 26878            29.0            82.0
# 26881           155.0             6.0
#
# [7249 rows x 21 columns]

# %%
import networkx as nx


passing_network = dict()
for team in teams:
    print(team)
    team_df = passes[passes['Team'] == team]
    
    # Be careful.  Not all events have players from the same team
    team_players = set(team_df['Player']) | set(team_df['Player 2'])
    team_players
    
    DG = nx.DiGraph()
    
    for i, pass_ in team_df.iterrows():
        
        DG.add_node(pass_['Player 2'])
        DG.add_node(pass_['Player'])
        if DG.has_edge(pass_['Player 2'], pass_['Player']):
            DG[pass_['Player 2'][pass_['Player']]['weight'] += 1
        else:
            DG.add_edge(pass_['Player 2'], pass_['Player'], weight= 1)
        
    break
    
DG.edges.data()
    
#     passing_network[team] = team_players
# passing_network
# Out:
# Metropolitan Riveters
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-bc0ffcea91e9> in <module>
#      18         DG.add_node(pass_['Player'])
#      19         if DG.has_edge(pass_['Player 2'], pass_['Player']):
# ---> 20             DG[pass_['Player 2'], pass_['Player']]['weight'] += 1
#      21         else:
#      22             DG.add_edge(pass_['Player 2'], pass_['Player'], weight= 1)
#
# ~/.virtualenvs/HockeyAnalysis/lib/python3.7/site-packages/networkx/classes/graph.py in __getitem__(self, n)
#     463         AtlasView({1: {}})
#     464         """
# --> 465         return self.adj[n]
#     466
#     467     def add_node(self, node_for_adding, **attr):
#
# ~/.virtualenvs/HockeyAnalysis/lib/python3.7/site-packages/networkx/classes/coreviews.py in __getitem__(self, name)
#      77
#      78     def __getitem__(self, name):
# ---> 79         return AtlasView(self._atlas[name])
#      80
#      81     def copy(self):
#
# KeyError: ('Sammy Kolowrat', 'Sonjia Shelly')

# %%
import matplotlib.pyplot as plt
nx.draw_spring(DG, with_labels=True, font_weight='bold')
